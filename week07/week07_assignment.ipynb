# %% [markdown]
# # Week 7 Assignment
#
# This week has been all about getting information off the internet both in structured data formats (CSV, JSON, etc) as well as HTML.  Answer the questions below as instructed.

# %% [markdown]
# ### 31.1 Finding files on the internet
#
# Go to healthdata.gov and find a file that looks interesting to you.  Provide the metadata below that describes the file you located.
#
# The cell below is a "markdown" cell.  Just double-click it to edit the contents and then Shift-Enter to show the content as formatted text.
#
# ---

# %% [markdown]
# **File Name:**  Prevention Agenda 2013 - 2017 Tracking Indicators: State Trend Data
#
# **URL to Page:** https://healthdata.gov/dataset/prevention-agenda-2013-2017-tracking-indicators-state-trend-data
#
# **Description:** This is one of the three datasets related to the Prevention Agenda Tracking Indicators state level data posted on this site. Each dataset consists of 58 state-level health tracking indicators and 31 sub-indicators for the Prevention Agenda 2013-2017: New York State’s Health Improvement Plan.
#
# **URL to Actual File:** https://health.data.ny.gov/api/views/m42a-gkda/rows.csv
#
# **File Format:** CSV

# %% [markdown]
# ---

# %% [markdown]
# ### 31.2 Use Pandas to load data from internet
#
# Now write a block of code (doesn't need to be in a function) that will load the file using Pandas and describe the shape of the file contents.  I've provided a cell with some comments in it to help get you started.
#
# Pandas documentation for loading data https://pandas.pydata.org/pandas-docs/version/0.23.4/api.html#input-output
#
# Pandas documentation for describing the shape of data https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.shape.html

# %%
import pandas as pd

# Load data using one of the read functions depending on your data file type
# data = pd.read_ ...

# Print out the row / column count
# data. ...

uri = "https://health.data.ny.gov/api/views/m42a-gkda/rows.csv"

data = pd.read_csv(uri)

df = pd.DataFrame(data)

print("The data is a table with the following dimensions: " + str(df.shape))

data
# Out:
# The data is a table with the following dimensions: (543, 17)
#      Priority Area Number                                      Priority Area  \
# 0                       0  Improve Health Status and Reduce Health Dispar...
# 1                       0  Improve Health Status and Reduce Health Dispar...
# 2                       0  Improve Health Status and Reduce Health Dispar...
# 3                       0  Improve Health Status and Reduce Health Dispar...
# 4                       0  Improve Health Status and Reduce Health Dispar...
# ..                    ...                                                ...
# 538                     5  Promote Mental Health and Prevent Substance Abuse
# 539                     5  Promote Mental Health and Prevent Substance Abuse
# 540                     5  Promote Mental Health and Prevent Substance Abuse
# 541                     5  Promote Mental Health and Prevent Substance Abuse
# 542                     5  Promote Mental Health and Prevent Substance Abuse
#
#      Focus Area Number                                         Focus Area  \
# 0                    0  Improve Health Status and Reduce Health Dispar...
# 1                    0  Improve Health Status and Reduce Health Dispar...
# 2                    0  Improve Health Status and Reduce Health Dispar...
# 3                    0  Improve Health Status and Reduce Health Dispar...
# 4                    0  Improve Health Status and Reduce Health Dispar...
# ..                 ...                                                ...
# 538                  2    Prevent Substance Abuse and Other MEB Disorders
# 539                  2    Prevent Substance Abuse and Other MEB Disorders
# 540                  2    Prevent Substance Abuse and Other MEB Disorders
# 541                  2    Prevent Substance Abuse and Other MEB Disorders
# 542                  2    Prevent Substance Abuse and Other MEB Disorders
#
#     Indicator Number                                          Indicator  \
# 0              pa1_0  Percentage of premature deaths (before age 65 ...
# 1              pa1_0  Percentage of premature deaths (before age 65 ...
# 2              pa1_0  Percentage of premature deaths (before age 65 ...
# 3              pa1_0  Percentage of premature deaths (before age 65 ...
# 4              pa1_0  Percentage of premature deaths (before age 65 ...
# ..               ...                                                ...
# 538           pa58_0        Age-adjusted suicide death rate per 100,000
# 539           pa59_0  Percentage of cigarette smoking among adults w...
# 540           pa59_0  Percentage of cigarette smoking among adults w...
# 541           pa59_0  Percentage of cigarette smoking among adults w...
# 542           pa59_0  Percentage of cigarette smoking among adults w...
#
#     Disparity  Event Count/Rate  Average Number of Denominator/Rate  \
# 0          No           35742.0                            147460.0
# 1          No           35549.0                            144873.0
# 2          No           35126.0                            144912.0
# 3          No           35351.0                            147105.0
# 4          No           35196.0                            147390.0
# ..        ...               ...                                 ...
# 538        No            1642.0                          19746227.0
# 539        No               NaN                                 NaN
# 540        No               NaN                                 NaN
# 541        No               NaN                                 NaN
# 542        No               NaN                                 NaN
#
#           Measure Unit  Percentage/Rate/Ratio  Lower Limit of 95% CI  \
# 0              Percent                   24.2                    NaN
# 1              Percent                   24.5                    NaN
# 2              Percent                   24.2                    NaN
# 3              Percent                   24.0                    NaN
# 4              Percent                   23.9                    NaN
# ..                 ...                    ...                    ...
# 538  Age-adjusted rate                    7.8                    NaN
# 539            Percent                   32.5                   28.4
# 540            Percent                   24.9                   20.4
# 541            Percent                   33.7                   29.1
# 542            Percent                   27.3                   23.0
#
#      Upper Limit of 95% CI  2018 Objective Objective Region Data Years  \
# 0                      NaN            21.8   New York State       2008
# 1                      NaN            21.8   New York State       2009
# 2                      NaN            21.8   New York State       2010
# 3                      NaN            21.8   New York State       2011
# 4                      NaN            21.8   New York State       2012
# ..                     ...             ...              ...        ...
# 538                    NaN             5.9   New York State       2014
# 539                   37.0            27.6   New York State       2011
# 540                   30.0            27.6   New York State       2012
# 541                   38.6            27.6   New York State       2013
# 542                   31.9            27.6   New York State       2014
#
#                                            Date Source
# 0                    Vital Records data as of May 2016
# 1                    Vital Records data as of May 2016
# 2                    Vital Records data as of May 2016
# 3                    Vital Records data as of May 2016
# 4                    Vital Records data as of May 2016
# ..                                                 ...
# 538                  Vital Records data as of May 2016
# 539  NYS Behavioral Risk Factor Surveillance System...
# 540  NYS Behavioral Risk Factor Surveillance System...
# 541  NYS Behavioral Risk Factor Surveillance System...
# 542  NYS Behavioral Risk Factor Surveillance System...
#
# [543 rows x 17 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### 32.1 HTML Basics
#
# HTML is a form of which othere data format we've talked about:
#
# > A) Binary
# >
# > B) eXtensible Markup Language
# >
# > C) JavaScript Object Notation
# >
# > D) HL7 FHIR

# %%
answer321 = "B"

# %% [markdown]
# ### 32.2 Things in HTML
#
# Which of the following is **not** a part of HTML:
#
# > A) element
# >
# > B) tag
# >
# > C) dictionary
# >
# > D) attribute

# %%
answer322 = "C"

# %% [markdown]
# ### 32.3 Parsing HTML in Python
#
# Which of the following packages can be used to extract a table of data from HTML using Python (include all that apply in a list):
#
# > A) lxml
# >
# > B) BeautifulSoup
# >
# > C) Pandas
# >
# > D) fuzzywuzzy

# %%
answer323 = ["A","B","C"]
